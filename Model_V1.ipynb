# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrew-Leduc/Protein_rna_modeling/blob/main/Model_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
v1 = [1,2,3,4,5]
v2 = [1,2,3,4,5]

plt.plot(v1,v2)
